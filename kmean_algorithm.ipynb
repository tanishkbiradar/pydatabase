# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            1       0.0       3
# 2            1       0.0       3
# 3            1       0.0       3
# 4            2       NaN       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1                            Braund, Mr. Owen Harris    male  22.0      1
# 2                            Braund, Mr. Owen Harris    male  22.0      1
# 3                            Braund, Mr. Owen Harris    male  22.0      1
# 4  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0  A/5 21171   7.2500   NaN        S
# 2      0  A/5 21171   7.2500   NaN        S
# 3      0  A/5 21171   7.2500   NaN        S
# 4      0   PC 17599  71.2833   C85        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  901 non-null    int64
#  1   Survived     897 non-null    float64
#  2   Pclass       901 non-null    int64
#  3   Name         901 non-null    object
#  4   Sex          901 non-null    object
#  5   Age          723 non-null    float64
#  6   SibSp        901 non-null    int64
#  7   Parch        901 non-null    int64
#  8   Ticket       901 non-null    object
#  9   Fare         898 non-null    float64
#  10  Cabin        211 non-null    object
#  11  Embarked     899 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.6+ KB

# %%
df.fillna(method = "bfill",inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              1       0.0       3
# 2              1       0.0       3
# 3              1       0.0       3
# 4              2       0.0       1
# ..           ...       ...     ...
# 896          887       0.0       2
# 897          888       1.0       1
# 898          889       0.0       3
# 899          890       1.0       1
# 900          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2                              Braund, Mr. Owen Harris    male  22.0      1
# 3                              Braund, Mr. Owen Harris    male  22.0      1
# 4    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 896                              Montvila, Rev. Juozas    male  27.0      0
# 897                       Graham, Miss. Margaret Edith  female  19.0      0
# 898           Johnston, Miss. Catherine Helen "Carrie"  female  26.0      1
# 899                              Behr, Mr. Karl Howell    male  26.0      0
# 900                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 0        0   A/5 21171   7.2500   C85        S
# 1        0   A/5 21171   7.2500   C85        S
# 2        0   A/5 21171   7.2500   C85        S
# 3        0   A/5 21171   7.2500   C85        S
# 4        0    PC 17599  71.2833   C85        C
# ..     ...         ...      ...   ...      ...
# 896      0      211536  13.0000   B42        S
# 897      0      112053  30.0000   B42        S
# 898      2  W./C. 6607  23.4500  C148        S
# 899      0      111369  30.0000  C148        C
# 900      0      370376   7.7500   NaN        Q
#
# [901 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  901 non-null    int64
#  1   Survived     901 non-null    float64
#  2   Pclass       901 non-null    int64
#  3   Name         901 non-null    object
#  4   Sex          901 non-null    object
#  5   Age          901 non-null    float64
#  6   SibSp        901 non-null    int64
#  7   Parch        901 non-null    int64
#  8   Ticket       901 non-null    object
#  9   Fare         901 non-null    float64
#  10  Cabin        900 non-null    object
#  11  Embarked     901 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 84.6+ KB

# %%
df.drop(['PassengerId','Name','Ticket','Fare','Cabin'],axis =1,inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0         0.0       3    male  22.0      1      0        S
# 1         0.0       3    male  22.0      1      0        S
# 2         0.0       3    male  22.0      1      0        S
# 3         0.0       3    male  22.0      1      0        S
# 4         0.0       1  female  38.0      1      0        C
# ..        ...     ...     ...   ...    ...    ...      ...
# 896       0.0       2    male  27.0      0      0        S
# 897       1.0       1  female  19.0      0      0        S
# 898       0.0       3  female  26.0      1      2        S
# 899       1.0       1    male  26.0      0      0        C
# 900       0.0       3    male  32.0      0      0        Q
#
# [901 rows x 7 columns]

# %%
x = pd.DataFrame(df.iloc[:,1:])

# %%
x
# Out:
#      Pclass     Sex   Age  SibSp  Parch Embarked
# 0         3    male  22.0      1      0        S
# 1         3    male  22.0      1      0        S
# 2         3    male  22.0      1      0        S
# 3         3    male  22.0      1      0        S
# 4         1  female  38.0      1      0        C
# ..      ...     ...   ...    ...    ...      ...
# 896       2    male  27.0      0      0        S
# 897       1  female  19.0      0      0        S
# 898       3  female  26.0      1      2        S
# 899       1    male  26.0      0      0        C
# 900       3    male  32.0      0      0        Q
#
# [901 rows x 6 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
tr = ColumnTransformer(transformers = [
    ('t1',OneHotEncoder(drop = "first",sparse = False),['Sex','Embarked'])
],remainder = "passthrough")

# %%
tr
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('t1',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['Sex', 'Embarked'])])

# %%
x = pd.DataFrame(tr.fit_transform(x),columns = x.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py:433, in _get_column_indices(X, key)
#     432 for col in columns:
# --> 433     col_idx = all_columns.get_loc(col)
#     434     if not isinstance(col_idx, numbers.Integral):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 x = pd.DataFrame(tr.fit_transform(x),columns = x.columns)
#
# File ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:672, in ColumnTransformer.fit_transform(self, X, y)
#     670 self._check_n_features(X, reset=True)
#     671 self._validate_transformers()
# --> 672 self._validate_column_callables(X)
#     673 self._validate_remainder(X)
#     675 result = self._fit_transform(X, y, _fit_transform_one)
#
# File ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:352, in ColumnTransformer._validate_column_callables(self, X)
#     350         columns = columns(X)
#     351     all_columns.append(columns)
# --> 352     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     354 self._columns = all_columns
#     355 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py:441, in _get_column_indices(X, key)
#     438             column_indices.append(col_idx)
#     440     except KeyError as e:
# --> 441         raise ValueError("A given column is not a column of the dataframe") from e
#     443     return column_indices
#     444 else:
#
# ValueError: A given column is not a column of the dataframe

# %%
x
# Out:
#        0    1    2    3     4    5    6
# 0    1.0  0.0  1.0  3.0  22.0  1.0  0.0
# 1    1.0  0.0  1.0  3.0  22.0  1.0  0.0
# 2    1.0  0.0  1.0  3.0  22.0  1.0  0.0
# 3    1.0  0.0  1.0  3.0  22.0  1.0  0.0
# 4    0.0  0.0  0.0  1.0  38.0  1.0  0.0
# ..   ...  ...  ...  ...   ...  ...  ...
# 896  1.0  0.0  1.0  2.0  27.0  0.0  0.0
# 897  0.0  0.0  1.0  1.0  19.0  0.0  0.0
# 898  0.0  0.0  1.0  3.0  26.0  1.0  2.0
# 899  1.0  0.0  0.0  1.0  26.0  0.0  0.0
# 900  1.0  1.0  0.0  3.0  32.0  0.0  0.0
#
# [901 rows x 7 columns]
