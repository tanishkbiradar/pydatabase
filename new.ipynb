# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('dataset/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns = ['PassengerId','Name','Ticket','Fare','Cabin'],inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0         0.0       3    male  22.0      1      0        S
# 1         NaN       1  female  38.0      1      0        C
# 2         NaN       3  female   NaN      0      0        S
# 3         NaN       1  female  35.0      1      0        S
# 4         0.0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886       0.0       2    male  27.0      0      0        S
# 887       1.0       1  female  19.0      0      0        S
# 888       0.0       3  female   NaN      1      2        S
# 889       1.0       1    male  26.0      0      0        C
# 890       0.0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
df.append(pd.DataFrame([[1,1,'female',38.0,1,0,'C']],columns = ['Survived','Pclass','Sex','Age','SibSp','Parch','Embarked']),ignore_index=True)
# Out:
# C:\Users\CS-L2-PC08\AppData\Local\Temp\ipykernel_1868\3825589234.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.DataFrame([[1,1,'female',38.0,1,0,'C']],columns = ['Survived','Pclass','Sex','Age','SibSp','Parch','Embarked']),ignore_index=True)
#      Survived  Pclass   Age  SibSp  Parch     Sex Embarked
# 0         0.0       3  22.0      1      0     NaN      NaN
# 1         0.0       1  38.0      1      0     NaN      NaN
# 2         0.0       3  35.0      0      0     NaN      NaN
# 3         0.0       1  35.0      1      0     NaN      NaN
# 4         0.0       3  35.0      0      0     NaN      NaN
# ..        ...     ...   ...    ...    ...     ...      ...
# 887       1.0       1  19.0      0      0     NaN      NaN
# 888       0.0       3  26.0      1      2     NaN      NaN
# 889       1.0       1  26.0      0      0     NaN      NaN
# ...

# %%
df.isnull().sum()
# Out:
# Survived      4
# Pclass        0
# Sex           0
# Age         178
# SibSp         0
# Parch         0
# Embarked      2
# dtype: int64

# %%
df.fillna(method = 'bfill',inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
fig,(ax1,ax2)=plt.subplots(ncols = 2,figsize=(10,7))
ax1.set_title('Before Scaling')
sns.kdeplot(df['Survived'],ax=ax1)
sns.kdeplot(df['Age'],ax=ax1)
# Out:
# <AxesSubplot:title={'center':'Before Scaling'}, xlabel='Survived', ylabel='Density'>

# %%
df.drop(columns=["Sex","Embarked"],inplace=True)
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch
# 0         0.0       3  22.0      1      0
# 1         0.0       1  38.0      1      0
# 2         0.0       3  35.0      0      0
# 3         0.0       1  35.0      1      0
# 4         0.0       3  35.0      0      0
# ..        ...     ...   ...    ...    ...
# 886       0.0       2  27.0      0      0
# 887       1.0       1  19.0      0      0
# 888       0.0       3  26.0      1      2
# 889       1.0       1  26.0      0      0
# 890       0.0       3  32.0      0      0
#
# [891 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(df)

# %%
scaler
# Out:
# array([[-0.7855316 ,  0.82737724, -0.54014483,  0.43279337, -0.47367361],
#        [-0.7855316 , -1.56610693,  0.55650378,  0.43279337, -0.47367361],
#        [-0.7855316 ,  0.82737724,  0.35088217, -0.4745452 , -0.47367361],
#        ...,
#        [-0.7855316 ,  0.82737724, -0.26598267,  0.43279337,  2.00893337],
#        [ 1.27302327, -1.56610693, -0.26598267, -0.4745452 , -0.47367361],
#        [-0.7855316 ,  0.82737724,  0.14526055, -0.4745452 , -0.47367361]])

# %%
scaler = pd.DataFrame(scaler,columns=df.columns)

# %%
scaler
# Out:
#      Survived    Pclass       Age     SibSp     Parch
# 0   -0.785532  0.827377 -0.540145  0.432793 -0.473674
# 1   -0.785532 -1.566107  0.556504  0.432793 -0.473674
# 2   -0.785532  0.827377  0.350882 -0.474545 -0.473674
# 3   -0.785532 -1.566107  0.350882  0.432793 -0.473674
# 4   -0.785532  0.827377  0.350882 -0.474545 -0.473674
# ..        ...       ...       ...       ...       ...
# 886 -0.785532 -0.369365 -0.197442 -0.474545 -0.473674
# 887  1.273023 -1.566107 -0.745766 -0.474545 -0.473674
# 888 -0.785532  0.827377 -0.265983  0.432793  2.008933
# 889  1.273023 -1.566107 -0.265983 -0.474545 -0.473674
# 890 -0.785532  0.827377  0.145261 -0.474545 -0.473674
#
# [891 rows x 5 columns]

# %%
fig,(ax1,ax2)=plt.subplots(ncols = 2,figsize=(10,7))
ax1.set_title('Before Scaling')
sns.kdeplot(scaler['Survived'],ax=ax1)
sns.kdeplot(scaler['Age'],ax=ax1)
# Out:
# <AxesSubplot:title={'center':'Before Scaling'}, xlabel='Survived', ylabel='Density'>
