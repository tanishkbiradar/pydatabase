# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/placement.csv")
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.distplot(df["cgpa"])
# Out:
# C:\Users\CS-L2-PC08\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cgpa', ylabel='Density'>

# %%
df["cgpa"].skew()
# Out:
# -0.014529938929314918

# %%
df["cgpa_zscore"] = df["cgpa"]-df["cgpa"].mean()/df["cgpa"].std()
df
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1    -4.112588
# 1    7.46                  38.0       1    -3.842588
# 2    7.54                  40.0       1    -3.762588
# 3    6.42                   8.0       1    -4.882588
# 4    7.23                  17.0       0    -4.072588
# ..    ...                   ...     ...          ...
# 995  8.87                  44.0       1    -2.432588
# 996  9.12                  65.0       1    -2.182588
# 997  4.89                  34.0       0    -6.412588
# 998  8.62                  46.0       1    -2.682588
# 999  4.90                  10.0       1    -6.402588
#
# [1000 rows x 4 columns]

# %%
ul = df["cgpa"].mean()+3*df["cgpa"].std()
ul
# Out:
# 8.808933625397177

# %%
ll = df["cgpa"].mean()-3*df["cgpa"].std()
ll
# Out:
# 5.113546374602842

# %%
df[(df["cgpa"]>ul) | (df["cgpa"]<ll)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -6.382588
# 995  8.87                  44.0       1    -2.432588
# 996  9.12                  65.0       1    -2.182588
# 997  4.89                  34.0       0    -6.412588
# 999  4.90                  10.0       1    -6.402588

# %%
df["cgpa"] = np.where(df["cgpa"]>ul,
                      ul,
                     np.where(df["cgpa"]<ll,
                     ll,
                     df["cgpa"]))
df
# Out:
#          cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.190000                  26.0       1    -4.112588
# 1    7.460000                  38.0       1    -3.842588
# 2    7.540000                  40.0       1    -3.762588
# 3    6.420000                   8.0       1    -4.882588
# 4    7.230000                  17.0       0    -4.072588
# ..        ...                   ...     ...          ...
# 995  8.808934                  44.0       1    -2.432588
# 996  8.808934                  65.0       1    -2.182588
# 997  5.113546                  34.0       0    -6.412588
# 998  8.620000                  46.0       1    -2.682588
# 999  5.113546                  10.0       1    -6.402588
#
# [1000 rows x 4 columns]

# %%
df
# Out:
#          cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.190000                  26.0       1    -4.112588
# 1    7.460000                  38.0       1    -3.842588
# 2    7.540000                  40.0       1    -3.762588
# 3    6.420000                   8.0       1    -4.882588
# 4    7.230000                  17.0       0    -4.072588
# ..        ...                   ...     ...          ...
# 995  8.808934                  44.0       1    -2.432588
# 996  8.808934                  65.0       1    -2.182588
# 997  5.113546                  34.0       0    -6.412588
# 998  8.620000                  46.0       1    -2.682588
# 999  5.113546                  10.0       1    -6.402588
#
# [1000 rows x 4 columns]

# %%
df1 = pd.read_csv("dataset/placement.csv")
df1
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed  cgpa_zscore
# count  1000.000000           1000.000000  1000.000000  1000.000000
# mean      6.961499             32.225000     0.489000    -4.341348
# std       0.612688             19.130822     0.500129     0.615898
# min       5.113546              0.000000     0.000000    -6.412588
# 25%       6.550000             17.000000     0.000000    -4.752588
# 50%       6.960000             28.000000     0.000000    -4.342588
# 75%       7.370000             44.000000     1.000000    -3.932588
# max       8.808934            100.000000     1.000000    -2.182588

# %%
Q1 = df["placement_exam_marks"].quantile(25.0)
