# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/spambase.csv')

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_req_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0          0.32            0.00              0.00                0.00
# 1          0.14            0.28              0.21                0.07
# 2          1.23            0.19              0.19                0.12
# 3          0.63            0.00              0.31                0.63
# 4          0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
df.isnull().sum()
# Out:
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_req_our                  0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# word_freq_lab                 0
# ...

# %%
df.duplicated().sum()
# Out:
# 391

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_req_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4210 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4210 non-null   float64
#  1   word_freq_address           4210 non-null   float64
#  2   word_freq_all               4210 non-null   float64
#  3   word_freq_3d                4210 non-null   float64
#  4   word_req_our                4210 non-null   float64
#  5   word_freq_over              4210 non-null   float64
#  6   word_freq_remove            4210 non-null   float64
#  7   word_freq_internet          4210 non-null   float64
#  8   word_freq_order             4210 non-null   float64
#  9   word_freq_mail              4210 non-null   float64
#  10  word_freq_receive           4210 non-null   float64
#  11  word_freq_will              4210 non-null   float64
#  12  word_freq_people            4210 non-null   float64
# ...

# %%
x = pd.DataFrame(df.iloc[:,:57])

# %%
x
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_req_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# 4600    0
# Name: spam, Length: 4210, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 2)

# %%
x_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 922             0.78               0.00           0.78           0.0
# 891             0.00               0.00           0.00           0.0
# 292             0.08               0.17           0.34           0.0
# 171             0.17               0.00           0.08           0.0
# 4091            0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 3699            0.00               0.00           0.00           0.0
# 1184            0.00               0.46           0.46           0.0
# 2689            0.00               0.00           3.44           0.0
# 3982            0.00               0.00           1.26           0.0
# 2757            0.00               0.00           0.00           0.0
#
#       word_req_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
x_test
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 2454            0.00               0.00           0.00           0.0
# 1456            0.00               0.51           0.00           0.0
# 1028            0.69               0.00           0.00           0.0
# 1373            0.00               0.00           0.29           0.0
# 1829            0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 464             0.00               0.00           0.00           0.0
# 4149            1.08               0.00           1.08           0.0
# 3741            0.00               0.00           0.00           0.0
# 3995            0.00               0.00           0.00           0.0
# 3210            0.02               0.08           0.10           0.0
#
#       word_req_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
y_train
# Out:
# 922     1
# 891     1
# 292     1
# 171     1
# 4091    0
#        ..
# 3699    0
# 1184    1
# 2689    0
# 3982    0
# 2757    0
# Name: spam, Length: 3368, dtype: int64

# %%
y_test
# Out:
# 2454    0
# 1456    1
# 1028    1
# 1373    1
# 1829    0
#        ..
# 464     1
# 4149    0
# 3741    0
# 3995    0
# 3210    0
# Name: spam, Length: 842, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
d = RandomForestClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = d.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9394299287410927

# %%
d.score(x_train,y_train)
# Out:
# 0.9994061757719715

# %%
d.score(x_test,y_test)
# Out:
# 0.9394299287410927

# %%
r1 = RandomForestClassifier(max_depth = 15,min_samples_split=20,max_features=1.0,random_state=10,max_samples=0.50)

# %%
r1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=15, max_features=1.0, max_samples=0.5,
#                        min_samples_split=20, random_state=10)

# %%
y_pred1 = r1.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9251781472684085

# %%
d.score(x_train,y_train)
# Out:
# 0.9994061757719715

# %%
d.score(x_test,y_test)
# Out:
# 0.9394299287410927

# %%
n_estimator = [12,13,14,15]
max_features = [0.5,0.6,0.2,0.1]
random_state = [10,20,30,40]

param_pred = {'n_estimator':n_estimator,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'max_features':max_features,
             'random_state':random_state}

# %%
r2 = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
r = GridSearchCV(estimator=r2,
                 param_grid = param_pred,
                 cv=6,
                 n_jobs = -1,
                 verbose = 2
            )
