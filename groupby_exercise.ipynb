# %%
import pandas as pd                       #import the required library and read the titanic dataframe
import numpy as np
df = pd.read_csv("dataset/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe() #this functions performs all the functions give in output
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  887.000000  891.000000  713.000000  891.000000
# mean    446.000000    0.382187    2.308642   29.704306    0.523008
# std     257.353842    0.486196    0.836071   14.536033    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  888.000000
# mean     0.381594   32.282530
# std      0.806057   49.758986
# min      0.000000    0.000000
# 25%      0.000000    7.917700
# 50%      0.000000   14.456250
# 75%      0.000000   31.068750
# max      6.000000  512.329200

# %%
df.info()  # it prints summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     887 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         888 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df.describe(include = "object")  #include function includes the given object values in describe function and execute
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.index # it prints number of index in given dataframe and start and step
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns  #it prints the columns present in dataframe
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()    # it displays first five rows of dataframe and more if you gives parameter in it
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female   NaN      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282      NaN   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull()  #it checks the null values and displays true for null value and false for notnull values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False      True   False  False  False  False  False  False   False
# 2          False      True   False  False  False   True  False  False   False
# 3          False      True   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()  #here we checks how many null values in dataframe using isnull().sum() functions
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[["Age"]].isnull().sum() #here we checks null values of age columns only
# Out:
# Age    178
# dtype: int64

# %%
df[["Age","Cabin"]].isnull().sum() #here we checks null values of age columns only
# Out:
# Age      178
# Cabin    687
# dtype: int64

# %%
df1 = df.drop(["PassengerId","Name","Ticket","Cabin"],axis = 1) #here we eliminated "PassengerId","Name","Ticket","Cabin" columns and stored it into df1 dataframe
df1
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         NaN       1  female  38.0      1      0  71.2833        C
# 2         NaN       3  female   NaN      0      0      NaN        S
# 3         NaN       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female   NaN      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df1.describe #it showes our data frame
df1
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         NaN       1  female  38.0      1      0  71.2833        C
# 2         NaN       3  female   NaN      0      0      NaN        S
# 3         NaN       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female   NaN      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df1.isnull().sum() #here we checks how many null values in dataframe using isnull().sum() functions
# Out:
# Survived      4
# Pclass        0
# Sex           0
# Age         178
# SibSp         0
# Parch         0
# Fare          3
# Embarked      2
# dtype: int64

# %%
df1[["Survived"]].fillna(method = "bfill").isnull().sum() #here we filled null values with before value of "Survived" column and we checks how many null values in dataframe using isnull().sum() function
# Out:
# Survived    0
# dtype: int64

# %%
df2=df1.fillna(method = "bfill") #here we stored filled null values in df2
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         0.0       1  female  38.0      1      0  71.2833        C
# 2         0.0       3  female  35.0      0      0  53.1000        S
# 3         0.0       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female  26.0      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
survived_count = df2.groupby("Survived")["Survived"].count()
survived_count
# Out:
# Survived
# 0.0    551
# 1.0    340
# Name: Survived, dtype: int64

# %%
Pclass_count = df2.groupby("Pclass")["Pclass"].count()
Pclass_count
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
Sex_count = df2.groupby('Sex')['Sex'].count()
Sex_count
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
Embark_count = df2.groupby('Embarked')["Embarked"].count()
Embark_count
# Out:
# Embarked
# C    169
# Q     77
# S    645
# Name: Embarked, dtype: int64

# %%
survived_count = df2.groupby("Sex")["Survived"].sum()
(survived_count)
# Out:
# Sex
# female    230.0
# male      110.0
# Name: Survived, dtype: float64

# %%
survived_count = df2.groupby(["Pclass","Sex","Survived"])["Survived"].count()
survived_count
# Out:
# Pclass  Sex     Survived
# 1       female  0.0           5
#                 1.0          89
#         male    0.0          77
#                 1.0          45
# 2       female  0.0           6
#                 1.0          70
#         male    0.0          91
#                 1.0          17
# 3       female  0.0          73
#                 1.0          71
#         male    0.0         299
#                 1.0          48
# Name: Survived, dtype: int64

# %%
a = df2.groupby("Pclass")["Survived"].count()
a
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
a = df2.groupby("Pclass")["Survived"].sum()
a
# Out:
# Pclass
# 1    134.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
a = df2.groupby("Pclass")["Survived"].sum()/df2.groupby("Pclass")["Survived"].count()*100
a
# Out:
# Pclass
# 1    62.037037
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
a = df2.groupby("Pclass")["Survived"].count()
a
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
a = df2.groupby("Pclass")["Survived"].sum()
a
# Out:
# Pclass
# 1    134.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
a = df2.groupby("Sex")["Survived"].sum()/df2.groupby("Sex")["Survived"].count()*100
a
# Out:
# Sex
# female    73.248408
# male      19.064125
# Name: Survived, dtype: float64

# %%
b= df2.groupby(["Embarked","Sex"])["Survived"].sum() #here we check how many people survived in each class based on sex
b
# Out:
# Embarked  Sex
# C         female     64.0
#           male       29.0
# Q         female     27.0
#           male        4.0
# S         female    139.0
#           male       77.0
# Name: Survived, dtype: float64
