# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("MPG") #mtcars data

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df["name"].nunique()
# Out:
# 305

# %%
df.drop(columns = ["name"],inplace = True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
df["origin"].nunique()
# Out:
# 3

# %%
x = pd.DataFrame(df)

# %%
x.drop(columns = ["mpg"],inplace = True) 
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0       usa
# 1       usa
# 2       usa
# 3       usa
# ...

# %%
y = pd.DataFrame(df["mpg"])

# %%
y.isnull().sum()
# Out:
# mpg    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 2)

# %%
x_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 204          4          85.0        70.0    1990          17.0          76
# 186          4         101.0        83.0    2202          15.3          76
# 3            8         304.0       150.0    3433          12.0          70
# 390          4         144.0        96.0    2665          13.9          82
# 193          6         200.0        81.0    3012          17.6          76
# ..         ...           ...         ...     ...           ...         ...
# 299          4         141.0        71.0    3190          24.8          79
# 22           4         104.0        95.0    2375          17.5          70
# 72           8         304.0       150.0    3892          12.5          72
# 15           6         198.0        95.0    2833          15.5          70
# 168          4         140.0        83.0    2639          17.0          75
#
#      origin
# 204   japan
# 186  europe
# 3       usa
# 390   japan
# ...

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 94           8         440.0       215.0    4735          11.0          73
# 32           4          98.0         NaN    2046          19.0          71
# 279          4          98.0        68.0    2135          16.6          78
# 178          4         120.0        88.0    2957          17.0          75
# 354          4         100.0         NaN    2320          15.8          81
# ..         ...           ...         ...     ...           ...         ...
# 298          8         350.0       125.0    3900          17.4          79
# 222          8         260.0       110.0    4060          19.0          77
# 65           8         351.0       153.0    4129          13.0          72
# 261          6         258.0       120.0    3410          15.1          78
# 342          4         135.0        84.0    2385          12.9          81
#
#      origin
# 94      usa
# 32      usa
# 279   japan
# 178  europe
# ...

# %%
y_train
# Out:
#       mpg
# 204  32.0
# 186  27.0
# 3    16.0
# 390  32.0
# 193  24.0
# ..    ...
# 299  27.2
# 22   25.0
# 72   15.0
# 15   22.0
# 168  23.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 94   13.0
# 32   25.0
# 279  29.5
# 178  23.0
# 354  34.5
# ..    ...
# 298  23.0
# 222  17.0
# 65   14.0
# 261  18.1
# 342  30.0
#
# [80 rows x 1 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
tr = ColumnTransformer(transformers=[
    ('tn1',OneHotEncoder(),['origin']),
    ('tn2',StandardScaler(),["weight"]),
    ('tn3',SimpleImputer(),["horsepower"])
],remainder='passthrough')

# %%
tr
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tn1', OneHotEncoder(), ['origin']),
#                                 ('tn2', StandardScaler(), ['weight']),
#                                 ('tn3', SimpleImputer(), ['horsepower'])])

# %%
a = tr.fit_transform(x_train)

# %%
b = tr.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(a,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(b)
# Out:
# array([[10.97915314],
#        [22.21753333],
#        [30.87592665],
#        [23.89995097],
#        [31.33788521],
#        [ 7.20427382],
#        [10.7534423 ],
#        [15.48157739],
#        [14.23105871],
#        [20.87079776],
#        [25.15140726],
#        [24.73372025],
#        [30.93728667],
#        [21.38105567],
#        [28.76197943],
#        [27.39150619],
#        [21.2561761 ],
#        [30.5807089 ],
#        [35.306612  ],
#        [15.39741753],
#        [31.60669592],
#        [21.5432606 ],
#        [25.71461035],
#        [28.73419472],
#        [11.86481782],
#        [20.30621563],
#        [21.50975765],
#        [20.82351913],
#        [33.75875727],
#        [20.76563085],
#        [27.98741355],
#        [31.66443528],
#        [19.99481821],
#        [29.82381082],
#        [11.19965846],
#        [30.83787998],
#        [23.41385691],
#        [27.01914355],
#        [ 5.73085398],
#        [32.3644768 ],
#        [18.94642601],
# ...
